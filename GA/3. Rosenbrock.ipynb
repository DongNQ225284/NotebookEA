# %% [markdown]
# ### Tối ưu hàm Rosenbrock
# Đầu vào:
# - Hàm Rosenbrock: $f_x = \sum_{i = 1}^{D - 1}{[100(x_{i + 1} - x_i^2)^2 + (1 - x_i)^2]}$
# - Số chiều: D
# - $x_i \in [lower, upper]$ với $i = [1...D]$
#
# Đầu ra:
# - Một lời giải $x = (x_1, x_2, ..., x_D)$
# - Giá trị nhỏ nhất $f_x$

# %%
import numpy as np # type: ignore
def Rosenbrock(x):
    return np.sum(100 * (x[1:] - np.square(x[:-1]))**2 + (1 - np.square(x[:-1])))

# %%
import numpy as np # type: ignore
import random
import copy
import matplotlib.pyplot as plt # type: ignore

# %%
class Problem:
    def __init__(self, D, LB, UB):
        self.D = D
        self.LB = LB
        self.UB = UB

# %%
def decode(x_en, problem: Problem):
    x = x_en * (problem.UB - problem.LB) + problem.LB
    return x

def get_fitness(x):
    # fx = np.sum(x**2)
    fx = np.sum(100 * (x[1:] - np.square(x[:-1]))**2 + (1 - np.square(x[:-1])))
    return -fx

# %%
class Individual:
    def __init__(self):
        self.chromosome = None
        self.fitness = None

    def genIndi(self, problem : Problem):
        self.chromosome = np.random.uniform(0.0, 1.0, problem.D)
    
    def cal_fitness(self, problem):
        sol = decode(self.chromosome, problem)
        self.fitness = get_fitness(sol)

    def clone(self):
        return copy.deepcopy(self)
    
    def __repr__(self):
        return f"chromosome={self.chromosome}, fitness={self.fitness:.2f})"

# %%
# Simulated binary crossover - SBX
def crossover(parent1, parent2, problem : Problem, eta = 2.0):
    off1 = Individual()
    off2 = Individual()
    r = np.random.rand()
    if (r <= 0.5):
        beta = (2*r)**(1.0/(eta + 1))
    else:
        beta = (1.0/(2*(1 - r)))**(1.0/(eta + 1))
    p1 = parent1.chromosome
    p2 = parent2.chromosome
    c1 = 0.5 * ((1 + beta) * p1 + (1 - beta) * p2)
    c2 = 0.5 * ((1 - beta) * p1 + (1 + beta) * p2)
    c1 = np.clip(c1, 0.0, 1.0)
    c2 = np.clip(c2, 0.0, 1.0)
    off1.chromosome = c1
    off2.chromosome = c2
    return off1.clone(), off2.clone()

# %%
# Polynomial mutaion - PM
def mutation(indi : Individual, eta = 20.0):
    chr = indi.chromosome
    for i in range(chr.size):
        mu = np.random.rand()
        if (mu <= 0.5):
            delta = (2 * mu)**(1.0/(1 + eta)) - 1
            chr[i] = chr[i] + delta * chr[i]
        else:
            delta = 1 - (2 - 2*mu)**(1.0/(1 + eta))
            chr[i] = chr[i] + delta * (1 - chr[i])
            
    chr = np.clip(chr, 0.0, 1.0)
    indi.chromosome = chr
    return indi.clone()

# %%
class Population:
    def __init__(self, pop_size, problem : Problem):
        self.pop_size = pop_size
        self.list_indi = []
        self.problem = problem
    
    def genPop(self):
        for i in range(self.pop_size):
            indi = Individual()
            indi.genIndi(self.problem)
            indi.cal_fitness(self.problem)
            self.list_indi.append(indi)

# %%
def selection(list, k = 2):
    tour1 = random.sample(list, k)
    tour2 = random.sample(list, k)
    x = max(tour1, key=lambda indi: indi.fitness)
    y = max(tour2, key=lambda indi: indi.fitness)
    return x.clone(), y.clone()

# %%
def survival_selection(list, pop_size):
    list = sorted(list, key=lambda indi: indi.fitness, reverse=True)
    list = list[0: pop_size]
    return list

# %%
def GA(problem, pop_size, max_gen, p_c, p_m):
    pop = Population(pop_size, problem)
    pop.genPop()
    history = []
    for i in range(max_gen):
        child = []
        while (len(child) < pop_size):
            p1, p2 = selection(pop.list_indi)
            if np.random.rand() <= p_c:
                c1, c2 = crossover(p1, p2, problem)
                c1.cal_fitness(problem)
                c2.cal_fitness(problem)
                child.append(c1)
                child.append(c2)
            if np.random.rand() <= p_m:
                p1 = mutation(p1)
                p2 = mutation(p2)
                p1.cal_fitness(problem)
                p2.cal_fitness(problem)
                child.append(p1)
                child.append(p2)
        pop.list_indi = survival_selection(pop.list_indi + child, pop_size)
        history.append(pop.list_indi[0].fitness)
    solution = pop.list_indi[0]
    return history, solution

# %%
# setup
D = 10
LB = -50
UB = 50
problem = Problem(D, LB, UB)

pop_size = 200
max_gen = 500
Pc = 0.9
Pm = 0.2

# start
fitness_history, solution = GA(problem, pop_size, max_gen, Pc, Pm)

#show
for i in range(len(fitness_history)):
    print(f"Generation {i}, best fitness = {fitness_history[i]:.2f}")
# Out:
# Generation 0, best fitness = -76908136.63
# Generation 1, best fitness = -27051380.05
# Generation 2, best fitness = -20346866.51
# Generation 3, best fitness = -13806855.16
# Generation 4, best fitness = -9430092.50
# Generation 5, best fitness = -2626897.51
# Generation 6, best fitness = -1645790.18
# Generation 7, best fitness = -1309068.94
# Generation 8, best fitness = -991535.13
# Generation 9, best fitness = -322166.16
# Generation 10, best fitness = -322166.16
# Generation 11, best fitness = -208318.32
# Generation 12, best fitness = -101860.79
# Generation 13, best fitness = -84407.53
# Generation 14, best fitness = -84149.36
# Generation 15, best fitness = -83798.53
# Generation 16, best fitness = -60206.88
# Generation 17, best fitness = -60206.88
# Generation 18, best fitness = -41597.71
# Generation 19, best fitness = -41597.71
# Generation 20, best fitness = -36938.15
# Generation 21, best fitness = -34605.82
# Generation 22, best fitness = -16703.07
# Generation 23, best fitness = -16703.07
# Generation 24, best fitness = -16107.44
# Generation 25, best fitness = -3540.47
# Generation 26, best fitness = -3514.60
# Generation 27, best fitness = -3490.73
# Generation 28, best fitness = -3490.73
# Generation 29, best fitness = -3298.43
# Generation 30, best fitness = -3121.15
# Generation 31, best fitness = -2166.15
# Generation 32, best fitness = -2166.15
# Generation 33, best fitness = -2166.15
# Generation 34, best fitness = -2069.18
# Generation 35, best fitness = -1835.92
# Generation 36, best fitness = -1828.16
# Generation 37, best fitness = -1828.16
# Generation 38, best fitness = -1813.09
# Generation 39, best fitness = -1803.70
# Generation 40, best fitness = -1737.70
# Generation 41, best fitness = -1728.00
# Generation 42, best fitness = -1728.00
# Generation 43, best fitness = -1727.76
# Generation 44, best fitness = -1694.96
# Generation 45, best fitness = -1694.96
# Generation 46, best fitness = -1694.94
# Generation 47, best fitness = -1694.94
# Generation 48, best fitness = -1686.24
# Generation 49, best fitness = -1684.60
# Generation 50, best fitness = -1683.29
# Generation 51, best fitness = -1678.47
# Generation 52, best fitness = -1675.78
# Generation 53, best fitness = -1675.78
# Generation 54, best fitness = -1675.78
# Generation 55, best fitness = -1674.94
# Generation 56, best fitness = -1596.21
# Generation 57, best fitness = -1422.59
# Generation 58, best fitness = -1422.59
# Generation 59, best fitness = -1372.85
# Generation 60, best fitness = -1325.47
# Generation 61, best fitness = -1291.72
# Generation 62, best fitness = -1291.72
# Generation 63, best fitness = -1282.75
# Generation 64, best fitness = -1277.19
# Generation 65, best fitness = -1265.97
# Generation 66, best fitness = -1263.58
# Generation 67, best fitness = -1259.38
# Generation 68, best fitness = -1245.28
# Generation 69, best fitness = -1237.64
# Generation 70, best fitness = -1237.64
# Generation 71, best fitness = -1234.41
# Generation 72, best fitness = -1231.43
# Generation 73, best fitness = -1229.30
# Generation 74, best fitness = -1221.38
# Generation 75, best fitness = -1221.38
# Generation 76, best fitness = -1217.11
# Generation 77, best fitness = -1209.33
# Generation 78, best fitness = -1208.55
# Generation 79, best fitness = -1201.75
# Generation 80, best fitness = -1201.75
# Generation 81, best fitness = -1201.75
# Generation 82, best fitness = -1199.82
# Generation 83, best fitness = -1198.14
# Generation 84, best fitness = -1196.30
# Generation 85, best fitness = -1192.14
# Generation 86, best fitness = -1191.72
# Generation 87, best fitness = -1188.91
# Generation 88, best fitness = -1188.84
# Generation 89, best fitness = -1186.36
# Generation 90, best fitness = -1185.44
# Generation 91, best fitness = -1184.28
# Generation 92, best fitness = -1184.20
# Generation 93, best fitness = -1183.16
# Generation 94, best fitness = -1182.97
# Generation 95, best fitness = -1181.97
# Generation 96, best fitness = -1177.13
# Generation 97, best fitness = -1175.01
# Generation 98, best fitness = -1174.17
# Generation 99, best fitness = -1174.17
# Generation 100, best fitness = -1173.01
# Generation 101, best fitness = -1172.80
# Generation 102, best fitness = -1172.21
# Generation 103, best fitness = -1170.35
# Generation 104, best fitness = -1170.35
# Generation 105, best fitness = -1170.35
# Generation 106, best fitness = -1170.04
# Generation 107, best fitness = -1168.37
# Generation 108, best fitness = -1166.76
# Generation 109, best fitness = -1166.76
# Generation 110, best fitness = -1165.81
# Generation 111, best fitness = -1162.29
# Generation 112, best fitness = -1161.80
# Generation 113, best fitness = -1160.12
# Generation 114, best fitness = -1158.68
# Generation 115, best fitness = -1155.82
# Generation 116, best fitness = -1154.90
# Generation 117, best fitness = -1153.06
# Generation 118, best fitness = -1152.93
# Generation 119, best fitness = -1152.25
# Generation 120, best fitness = -1151.90
# Generation 121, best fitness = -1150.33
# Generation 122, best fitness = -1149.61
# Generation 123, best fitness = -1149.61
# Generation 124, best fitness = -1149.11
# Generation 125, best fitness = -1148.16
# Generation 126, best fitness = -1148.10
# Generation 127, best fitness = -1146.26
# Generation 128, best fitness = -1146.16
# Generation 129, best fitness = -1146.16
# Generation 130, best fitness = -1145.91
# Generation 131, best fitness = -1145.91
# Generation 132, best fitness = -1145.08
# Generation 133, best fitness = -1145.08
# Generation 134, best fitness = -1145.08
# Generation 135, best fitness = -1144.36
# Generation 136, best fitness = -1144.36
# Generation 137, best fitness = -1141.77
# Generation 138, best fitness = -1141.77
# Generation 139, best fitness = -1139.42
# Generation 140, best fitness = -1137.77
# Generation 141, best fitness = -1135.49
# Generation 142, best fitness = -1135.34
# Generation 143, best fitness = -1135.34
# Generation 144, best fitness = -1134.61
# Generation 145, best fitness = -1134.13
# Generation 146, best fitness = -1134.09
# Generation 147, best fitness = -1134.00
# Generation 148, best fitness = -1133.85
# Generation 149, best fitness = -1133.69
# Generation 150, best fitness = -1133.69
# Generation 151, best fitness = -1133.69
# Generation 152, best fitness = -1133.69
# Generation 153, best fitness = -1133.69
# Generation 154, best fitness = -1133.54
# Generation 155, best fitness = -1133.53
# Generation 156, best fitness = -1133.44
# Generation 157, best fitness = -1133.43
# Generation 158, best fitness = -1133.43
# Generation 159, best fitness = -1133.43
# Generation 160, best fitness = -1133.35
# Generation 161, best fitness = -1133.31
# Generation 162, best fitness = -1133.31
# Generation 163, best fitness = -1133.31
# Generation 164, best fitness = -1133.23
# Generation 165, best fitness = -1133.19
# Generation 166, best fitness = -1133.17
# Generation 167, best fitness = -1133.03
# Generation 168, best fitness = -1133.03
# Generation 169, best fitness = -1132.98
# Generation 170, best fitness = -1132.90
# Generation 171, best fitness = -1132.90
# Generation 172, best fitness = -1132.87
# Generation 173, best fitness = -1132.86
# Generation 174, best fitness = -1132.75
# Generation 175, best fitness = -1132.75
# Generation 176, best fitness = -1132.71
# Generation 177, best fitness = -1132.66
# Generation 178, best fitness = -1132.62
# Generation 179, best fitness = -1132.57
# Generation 180, best fitness = -1132.57
# Generation 181, best fitness = -1132.50
# Generation 182, best fitness = -1132.46
# Generation 183, best fitness = -1132.46
# Generation 184, best fitness = -1132.37
# Generation 185, best fitness = -1132.37
# Generation 186, best fitness = -1132.35
# Generation 187, best fitness = -1132.34
# Generation 188, best fitness = -1132.26
# Generation 189, best fitness = -1132.26
# Generation 190, best fitness = -1132.25
# Generation 191, best fitness = -1132.24
# Generation 192, best fitness = -1132.24
# Generation 193, best fitness = -1132.20
# Generation 194, best fitness = -1132.20
# Generation 195, best fitness = -1132.18
# Generation 196, best fitness = -1132.18
# Generation 197, best fitness = -1132.17
# Generation 198, best fitness = -1132.17
# Generation 199, best fitness = -1132.09
# Generation 200, best fitness = -1132.04
# Generation 201, best fitness = -1132.04
# Generation 202, best fitness = -1132.01
# Generation 203, best fitness = -1131.98
# Generation 204, best fitness = -1131.95
# Generation 205, best fitness = -1131.90
# Generation 206, best fitness = -1131.89
# Generation 207, best fitness = -1131.87
# Generation 208, best fitness = -1131.87
# Generation 209, best fitness = -1131.86
# Generation 210, best fitness = -1131.84
# Generation 211, best fitness = -1131.84
# Generation 212, best fitness = -1131.82
# Generation 213, best fitness = -1131.82
# Generation 214, best fitness = -1131.82
# Generation 215, best fitness = -1131.80
# Generation 216, best fitness = -1131.80
# Generation 217, best fitness = -1131.79
# Generation 218, best fitness = -1131.79
# Generation 219, best fitness = -1131.79
# Generation 220, best fitness = -1131.77
# Generation 221, best fitness = -1131.77
# Generation 222, best fitness = -1131.77
# Generation 223, best fitness = -1131.75
# Generation 224, best fitness = -1131.74
# Generation 225, best fitness = -1131.74
# Generation 226, best fitness = -1131.74
# Generation 227, best fitness = -1131.72
# Generation 228, best fitness = -1131.72
# Generation 229, best fitness = -1131.69
# Generation 230, best fitness = -1131.67
# Generation 231, best fitness = -1131.65
# Generation 232, best fitness = -1131.65
# Generation 233, best fitness = -1131.63
# Generation 234, best fitness = -1131.63
# Generation 235, best fitness = -1131.59
# Generation 236, best fitness = -1131.59
# Generation 237, best fitness = -1131.59
# Generation 238, best fitness = -1131.58
# Generation 239, best fitness = -1131.47
# Generation 240, best fitness = -1131.45
# Generation 241, best fitness = -1131.45
# Generation 242, best fitness = -1131.43
# Generation 243, best fitness = -1131.42
# Generation 244, best fitness = -1131.42
# Generation 245, best fitness = -1131.41
# Generation 246, best fitness = -1131.40
# Generation 247, best fitness = -1131.39
# Generation 248, best fitness = -1131.38
# Generation 249, best fitness = -1131.31
# Generation 250, best fitness = -1131.31
# Generation 251, best fitness = -1131.31
# Generation 252, best fitness = -1131.30
# Generation 253, best fitness = -1131.16
# Generation 254, best fitness = -1131.14
# Generation 255, best fitness = -1131.10
# Generation 256, best fitness = -1131.10
# Generation 257, best fitness = -1131.06
# Generation 258, best fitness = -1130.96
# Generation 259, best fitness = -1130.71
# Generation 260, best fitness = -1130.71
# Generation 261, best fitness = -1130.08
# Generation 262, best fitness = -1130.08
# Generation 263, best fitness = -1129.71
# Generation 264, best fitness = -1129.29
# Generation 265, best fitness = -1128.96
# Generation 266, best fitness = -1128.53
# Generation 267, best fitness = -1128.29
# Generation 268, best fitness = -1127.56
# Generation 269, best fitness = -1126.93
# Generation 270, best fitness = -1126.60
# Generation 271, best fitness = -1125.69
# Generation 272, best fitness = -1123.86
# Generation 273, best fitness = -1123.86
# Generation 274, best fitness = -1122.12
# Generation 275, best fitness = -1122.00
# Generation 276, best fitness = -1119.72
# Generation 277, best fitness = -1119.72
# Generation 278, best fitness = -1119.16
# Generation 279, best fitness = -1119.16
# Generation 280, best fitness = -1117.11
# Generation 281, best fitness = -1115.76
# Generation 282, best fitness = -1114.08
# Generation 283, best fitness = -1114.08
# Generation 284, best fitness = -1113.15
# Generation 285, best fitness = -1112.96
# Generation 286, best fitness = -1111.04
# Generation 287, best fitness = -1109.65
# Generation 288, best fitness = -1109.65
# Generation 289, best fitness = -1107.77
# Generation 290, best fitness = -1107.77
# Generation 291, best fitness = -1107.28
# Generation 292, best fitness = -1106.31
# Generation 293, best fitness = -1105.12
# Generation 294, best fitness = -1105.12
# Generation 295, best fitness = -1105.04
# Generation 296, best fitness = -1104.84
# Generation 297, best fitness = -1102.90
# Generation 298, best fitness = -1101.81
# Generation 299, best fitness = -1101.00
# Generation 300, best fitness = -1094.02
# Generation 301, best fitness = -1092.38
# Generation 302, best fitness = -1083.90
# Generation 303, best fitness = -1083.86
# Generation 304, best fitness = -1077.75
# Generation 305, best fitness = -1077.75
# Generation 306, best fitness = -1077.32
# Generation 307, best fitness = -1076.28
# Generation 308, best fitness = -1074.22
# Generation 309, best fitness = -1073.08
# Generation 310, best fitness = -1073.08
# Generation 311, best fitness = -1070.77
# Generation 312, best fitness = -1070.13
# Generation 313, best fitness = -1066.98
# Generation 314, best fitness = -1066.89
# Generation 315, best fitness = -1066.41
# Generation 316, best fitness = -1064.38
# Generation 317, best fitness = -1060.68
# Generation 318, best fitness = -1060.68
# Generation 319, best fitness = -1060.68
# Generation 320, best fitness = -1059.09
# Generation 321, best fitness = -1054.46
# Generation 322, best fitness = -1053.89
# Generation 323, best fitness = -1052.73
# Generation 324, best fitness = -1046.44
# Generation 325, best fitness = -1046.44
# Generation 326, best fitness = -1046.44
# Generation 327, best fitness = -1044.43
# Generation 328, best fitness = -1043.66
# Generation 329, best fitness = -1043.26
# Generation 330, best fitness = -1043.19
# Generation 331, best fitness = -1042.95
# Generation 332, best fitness = -1042.67
# Generation 333, best fitness = -1042.61
# Generation 334, best fitness = -1042.61
# Generation 335, best fitness = -1042.58
# Generation 336, best fitness = -1042.50
# Generation 337, best fitness = -1042.48
# Generation 338, best fitness = -1042.48
# Generation 339, best fitness = -1042.31
# Generation 340, best fitness = -1042.31
# Generation 341, best fitness = -1042.30
# Generation 342, best fitness = -1042.29
# Generation 343, best fitness = -1042.28
# Generation 344, best fitness = -1042.27
# Generation 345, best fitness = -1042.25
# Generation 346, best fitness = -1042.25
# Generation 347, best fitness = -1042.25
# Generation 348, best fitness = -1042.24
# Generation 349, best fitness = -1042.23
# Generation 350, best fitness = -1042.23
# Generation 351, best fitness = -1042.22
# Generation 352, best fitness = -1042.22
# Generation 353, best fitness = -1042.22
# Generation 354, best fitness = -1042.21
# Generation 355, best fitness = -1042.20
# Generation 356, best fitness = -1042.20
# Generation 357, best fitness = -1042.18
# Generation 358, best fitness = -1042.17
# Generation 359, best fitness = -1042.13
# Generation 360, best fitness = -1042.13
# Generation 361, best fitness = -1042.11
# Generation 362, best fitness = -1042.09
# Generation 363, best fitness = -1042.09
# Generation 364, best fitness = -1042.09
# Generation 365, best fitness = -1042.09
# Generation 366, best fitness = -1042.09
# Generation 367, best fitness = -1042.08
# Generation 368, best fitness = -1042.07
# Generation 369, best fitness = -1042.06
# Generation 370, best fitness = -1042.06
# Generation 371, best fitness = -1042.05
# Generation 372, best fitness = -1042.05
# Generation 373, best fitness = -1042.04
# Generation 374, best fitness = -1042.04
# Generation 375, best fitness = -1042.04
# Generation 376, best fitness = -1042.04
# Generation 377, best fitness = -1042.04
# Generation 378, best fitness = -1042.03
# Generation 379, best fitness = -1042.03
# Generation 380, best fitness = -1042.03
# Generation 381, best fitness = -1042.03
# Generation 382, best fitness = -1042.03
# Generation 383, best fitness = -1042.03
# Generation 384, best fitness = -1042.03
# Generation 385, best fitness = -1042.03
# Generation 386, best fitness = -1042.03
# Generation 387, best fitness = -1042.03
# Generation 388, best fitness = -1042.03
# Generation 389, best fitness = -1042.03
# Generation 390, best fitness = -1042.03
# Generation 391, best fitness = -1042.03
# Generation 392, best fitness = -1042.03
# Generation 393, best fitness = -1042.03
# Generation 394, best fitness = -1042.03
# Generation 395, best fitness = -1042.03
# Generation 396, best fitness = -1042.03
# Generation 397, best fitness = -1042.03
# Generation 398, best fitness = -1042.03
# Generation 399, best fitness = -1042.03
# Generation 400, best fitness = -1042.03
# Generation 401, best fitness = -1042.03
# Generation 402, best fitness = -1042.03
# Generation 403, best fitness = -1042.03
# Generation 404, best fitness = -1042.03
# Generation 405, best fitness = -1042.03
# Generation 406, best fitness = -1042.03
# Generation 407, best fitness = -1042.03
# Generation 408, best fitness = -1042.03
# Generation 409, best fitness = -1042.03
# Generation 410, best fitness = -1042.03
# Generation 411, best fitness = -1042.03
# Generation 412, best fitness = -1042.03
# Generation 413, best fitness = -1042.03
# Generation 414, best fitness = -1042.03
# Generation 415, best fitness = -1042.03
# Generation 416, best fitness = -1042.03
# Generation 417, best fitness = -1042.03
# Generation 418, best fitness = -1042.03
# Generation 419, best fitness = -1042.03
# Generation 420, best fitness = -1042.03
# Generation 421, best fitness = -1042.03
# Generation 422, best fitness = -1042.03
# Generation 423, best fitness = -1042.03
# Generation 424, best fitness = -1042.03
# Generation 425, best fitness = -1042.03
# Generation 426, best fitness = -1042.03
# Generation 427, best fitness = -1042.03
# Generation 428, best fitness = -1042.03
# Generation 429, best fitness = -1042.03
# Generation 430, best fitness = -1042.03
# Generation 431, best fitness = -1042.03
# Generation 432, best fitness = -1042.03
# Generation 433, best fitness = -1042.03
# Generation 434, best fitness = -1042.03
# Generation 435, best fitness = -1042.03
# Generation 436, best fitness = -1042.03
# Generation 437, best fitness = -1042.03
# Generation 438, best fitness = -1042.03
# Generation 439, best fitness = -1042.03
# Generation 440, best fitness = -1042.03
# Generation 441, best fitness = -1042.03
# Generation 442, best fitness = -1042.03
# Generation 443, best fitness = -1042.03
# Generation 444, best fitness = -1042.03
# Generation 445, best fitness = -1042.03
# Generation 446, best fitness = -1042.03
# Generation 447, best fitness = -1042.03
# Generation 448, best fitness = -1042.03
# Generation 449, best fitness = -1042.03
# Generation 450, best fitness = -1042.03
# Generation 451, best fitness = -1042.03
# Generation 452, best fitness = -1042.03
# Generation 453, best fitness = -1042.03
# Generation 454, best fitness = -1042.03
# Generation 455, best fitness = -1042.03
# Generation 456, best fitness = -1042.03
# Generation 457, best fitness = -1042.03
# Generation 458, best fitness = -1042.03
# Generation 459, best fitness = -1042.03
# Generation 460, best fitness = -1042.03
# Generation 461, best fitness = -1042.03
# Generation 462, best fitness = -1042.03
# Generation 463, best fitness = -1042.03
# Generation 464, best fitness = -1042.03
# Generation 465, best fitness = -1042.03
# Generation 466, best fitness = -1042.03
# Generation 467, best fitness = -1042.03
# Generation 468, best fitness = -1042.03
# Generation 469, best fitness = -1042.03
# Generation 470, best fitness = -1042.03
# Generation 471, best fitness = -1042.03
# Generation 472, best fitness = -1042.03
# Generation 473, best fitness = -1042.03
# Generation 474, best fitness = -1042.03
# Generation 475, best fitness = -1042.03
# Generation 476, best fitness = -1042.03
# Generation 477, best fitness = -1042.03
# Generation 478, best fitness = -1042.03
# Generation 479, best fitness = -1042.03
# Generation 480, best fitness = -1042.03
# Generation 481, best fitness = -1042.03
# Generation 482, best fitness = -1042.03
# Generation 483, best fitness = -1042.03
# Generation 484, best fitness = -1042.03
# Generation 485, best fitness = -1042.03
# Generation 486, best fitness = -1042.03
# Generation 487, best fitness = -1042.03
# Generation 488, best fitness = -1042.03
# Generation 489, best fitness = -1042.03
# Generation 490, best fitness = -1042.03
# Generation 491, best fitness = -1042.03
# Generation 492, best fitness = -1042.03
# Generation 493, best fitness = -1042.03
# Generation 494, best fitness = -1042.03
# Generation 495, best fitness = -1042.03
# Generation 496, best fitness = -1042.03
# Generation 497, best fitness = -1042.03
# Generation 498, best fitness = -1042.03
# Generation 499, best fitness = -1042.03

# %%
np.set_printoptions(precision=2, suppress=True)
print("solution:")
print(decode(solution.chromosome, problem))
print(f"The Rosenbrock value is: {- solution.fitness:.2f}")
# Out:
# solution:
# [-0.02  0.96 -0.12  0.85  0.93  1.24  0.86 -0.09 -0.28 -2.43]
# The Rosenbrock value is: 1042.03

# %%
generations = list(range(len(fitness_history)))
plt.figure(figsize=(10, 5))
plt.plot(generations, fitness_history, marker='o', linestyle='-', color='b', label='Best Fitness')

plt.xlabel("Generation")
plt.ylabel("Best Fitness")
plt.title("Fitness Progress Over Generations")
plt.legend()
plt.grid(True)
plt.show()
