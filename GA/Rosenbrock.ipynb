# %% [markdown]
# ### Tối ưu hàm Rosenbrock
# Đầu vào:
# - Hàm Rosenbrock: $f_x = \sum_{i = 1}^{D - 1}{[100(x_{i + 1} - x_i^2)^2 + (1 - x_i)^2]}$
# - Số chiều: D
# - $x_i \in [lower, upper]$ với $i = [1...D]$
#
# Đầu ra:
# - Một lời giải $x = (x_1, x_2, ..., x_D)$
# - Giá trị nhỏ nhất $f_x$

# %%
import numpy as np # type: ignore
def Rosenbrock(x):
    return np.sum(100 * (x[1:] - np.square(x[:-1]))**2 + (1 - np.square(x[:-1])))

# %%
import numpy as np # type: ignore
import random
import copy
import matplotlib.pyplot as plt # type: ignore

# %%
class Problem:
    def __init__(self, D, LB, UB):
        self.D = D
        self.LB = LB
        self.UB = UB

# %%
def decode(x_en, problem: Problem):
    x = x_en * (problem.UB - problem.LB) + problem.LB
    return x

def get_fitness(x):
    # fx = np.sum(x**2)
    fx = np.sum(100 * (x[1:] - np.square(x[:-1]))**2 + (1 - np.square(x[:-1])))
    return -fx

# %%
class Individual:
    def __init__(self):
        self.chromosome = None
        self.fitness = None

    def genIndi(self, problem : Problem):
        self.chromosome = np.random.uniform(0.0, 1.0, problem.D)
    
    def cal_fitness(self, problem):
        sol = decode(self.chromosome, problem)
        self.fitness = get_fitness(sol)

    def clone(self):
        return copy.deepcopy(self)
    
    def __repr__(self):
        return f"chromosome={self.chromosome}, fitness={self.fitness:.2f})"

# %%
# Simulated binary crossover - SBX
def crossover(parent1, parent2, problem : Problem, eta = 2.0):
    off1 = Individual()
    off2 = Individual()
    r = np.random.rand()
    if (r <= 0.5):
        beta = (2*r)**(1.0/(eta + 1))
    else:
        beta = (1.0/(2*(1 - r)))**(1.0/(eta + 1))
    p1 = parent1.chromosome
    p2 = parent2.chromosome
    c1 = 0.5 * ((1 + beta) * p1 + (1 - beta) * p2)
    c2 = 0.5 * ((1 - beta) * p1 + (1 + beta) * p2)
    c1 = np.clip(c1, 0.0, 1.0)
    c2 = np.clip(c2, 0.0, 1.0)
    off1.chromosome = c1
    off2.chromosome = c2
    return off1.clone(), off2.clone()

# %%
# Polynomial mutaion - PM
def mutation(indi : Individual, eta = 20.0):
    chr = indi.chromosome
    for i in range(chr.size):
        mu = np.random.rand()
        if (mu <= 0.5):
            delta = (2 * mu)**(1.0/(1 + eta)) - 1
            chr[i] = chr[i] + delta * chr[i]
        else:
            delta = 1 - (2 - 2*mu)**(1.0/(1 + eta))
            chr[i] = chr[i] + delta * (1 - chr[i])
            
    chr = np.clip(chr, 0.0, 1.0)
    indi.chromosome = chr
    return indi.clone()

# %%
class Population:
    def __init__(self, pop_size, problem : Problem):
        self.pop_size = pop_size
        self.list_indi = []
        self.problem = problem
    
    def genPop(self):
        for i in range(self.pop_size):
            indi = Individual()
            indi.genIndi(self.problem)
            indi.cal_fitness(self.problem)
            self.list_indi.append(indi)

# %%
def selection(list, k = 2):
    tour1 = random.sample(list, k)
    tour2 = random.sample(list, k)
    x = max(tour1, key=lambda indi: indi.fitness)
    y = max(tour2, key=lambda indi: indi.fitness)
    return x.clone(), y.clone()

# %%
def survival_selection(list, pop_size):
    list = sorted(list, key=lambda indi: indi.fitness, reverse=True)
    list = list[0: pop_size]
    return list

# %%
def GA(problem, pop_size, max_gen, p_c, p_m):
    pop = Population(pop_size, problem)
    pop.genPop()
    history = []
    for i in range(max_gen):
        child = []
        while (len(child) < pop_size):
            p1, p2 = selection(pop.list_indi)
            if np.random.rand() <= p_c:
                c1, c2 = crossover(p1, p2, problem)
                c1.cal_fitness(problem)
                c2.cal_fitness(problem)
                child.append(c1)
                child.append(c2)
            if np.random.rand() <= p_m:
                p1 = mutation(p1)
                p2 = mutation(p2)
                p1.cal_fitness(problem)
                p2.cal_fitness(problem)
                child.append(p1)
                child.append(p2)
        pop.list_indi = survival_selection(pop.list_indi + child, pop_size)
        history.append(pop.list_indi[0].fitness)
    solution = pop.list_indi[0]
    return history, solution

# %%
# setup
D = 10
LB = -50
UB = 50
problem = Problem(D, LB, UB)

pop_size = 200
max_gen = 500
Pc = 0.9
Pm = 0.2

# start
fitness_history, solution = GA(problem, pop_size, max_gen, Pc, Pm)

#show
for i in range(len(fitness_history)):
    print(f"Generation {i}, best fitness = {fitness_history[i]:.2f}")
# Out:
# Generation 0, best fitness = -55243139.19
# Generation 1, best fitness = -27082004.68
# Generation 2, best fitness = -27082004.68
# Generation 3, best fitness = -18059855.61
# Generation 4, best fitness = -10722435.10
# Generation 5, best fitness = -1602550.80
# Generation 6, best fitness = -1602550.80
# Generation 7, best fitness = -846661.47
# Generation 8, best fitness = -730229.11
# Generation 9, best fitness = -537907.64
# Generation 10, best fitness = -329684.16
# Generation 11, best fitness = -282217.02
# Generation 12, best fitness = -158758.18
# Generation 13, best fitness = -139058.95
# Generation 14, best fitness = -42194.27
# Generation 15, best fitness = -41921.09
# Generation 16, best fitness = -41921.09
# Generation 17, best fitness = -37777.37
# Generation 18, best fitness = -23724.65
# Generation 19, best fitness = -23442.31
# Generation 20, best fitness = -18551.73
# Generation 21, best fitness = -17109.82
# Generation 22, best fitness = -15875.56
# Generation 23, best fitness = -14461.53
# Generation 24, best fitness = -6207.08
# Generation 25, best fitness = -6207.08
# Generation 26, best fitness = -6207.08
# Generation 27, best fitness = -5003.08
# Generation 28, best fitness = -4657.01
# Generation 29, best fitness = -4608.22
# Generation 30, best fitness = -4608.22
# Generation 31, best fitness = -4330.90
# Generation 32, best fitness = -3721.19
# Generation 33, best fitness = -3721.19
# Generation 34, best fitness = -3709.78
# Generation 35, best fitness = -2931.93
# Generation 36, best fitness = -2631.00
# Generation 37, best fitness = -2573.99
# Generation 38, best fitness = -2573.99
# Generation 39, best fitness = -2559.95
# Generation 40, best fitness = -2544.70
# Generation 41, best fitness = -2544.70
# Generation 42, best fitness = -2544.70
# Generation 43, best fitness = -2544.70
# Generation 44, best fitness = -2541.84
# Generation 45, best fitness = -2537.23
# Generation 46, best fitness = -2533.90
# Generation 47, best fitness = -2527.67
# Generation 48, best fitness = -2525.64
# Generation 49, best fitness = -2524.74
# Generation 50, best fitness = -2522.27
# Generation 51, best fitness = -2522.27
# Generation 52, best fitness = -2521.94
# Generation 53, best fitness = -2521.94
# Generation 54, best fitness = -2521.94
# Generation 55, best fitness = -2520.92
# Generation 56, best fitness = -2520.80
# Generation 424, best fitness = -931.43
# Generation 425, best fitness = -931.43
# Generation 426, best fitness = -931.43
# Generation 427, best fitness = -931.43
# Generation 428, best fitness = -931.43
# Generation 429, best fitness = -931.43
# Generation 430, best fitness = -931.43
# Generation 431, best fitness = -931.43
# Generation 432, best fitness = -931.43
# Generation 433, best fitness = -931.43
# Generation 434, best fitness = -931.43
# Generation 435, best fitness = -931.43
# Generation 436, best fitness = -931.43
# Generation 437, best fitness = -931.43
# Generation 438, best fitness = -931.43
# Generation 439, best fitness = -931.43
# Generation 440, best fitness = -931.43
# Generation 441, best fitness = -931.43
# Generation 442, best fitness = -931.43
# Generation 443, best fitness = -931.43
# Generation 444, best fitness = -931.43
# Generation 445, best fitness = -931.43
# Generation 446, best fitness = -931.43
# Generation 447, best fitness = -931.43
# Generation 448, best fitness = -931.43
# Generation 449, best fitness = -931.43
# Generation 450, best fitness = -931.43
# Generation 451, best fitness = -931.43
# Generation 452, best fitness = -931.43
# Generation 453, best fitness = -931.43
# Generation 454, best fitness = -931.43
# Generation 455, best fitness = -931.43
# Generation 456, best fitness = -931.43
# Generation 457, best fitness = -931.43
# Generation 458, best fitness = -931.43
# Generation 459, best fitness = -931.43
# Generation 460, best fitness = -931.43
# Generation 461, best fitness = -931.43
# Generation 462, best fitness = -931.43
# Generation 463, best fitness = -931.43
# Generation 464, best fitness = -931.43
# Generation 465, best fitness = -931.43
# Generation 466, best fitness = -931.43
# Generation 467, best fitness = -931.43
# Generation 468, best fitness = -931.43
# Generation 469, best fitness = -931.43
# Generation 470, best fitness = -931.43
# Generation 471, best fitness = -931.43
# Generation 472, best fitness = -931.43
# Generation 473, best fitness = -931.43
# Generation 474, best fitness = -931.43
# Generation 475, best fitness = -931.43
# Generation 476, best fitness = -931.43
# Generation 477, best fitness = -931.43
# Generation 478, best fitness = -931.43
# Generation 479, best fitness = -931.43
# Generation 480, best fitness = -931.43
# Generation 481, best fitness = -931.43
# Generation 482, best fitness = -931.43
# Generation 483, best fitness = -931.43
# Generation 484, best fitness = -931.43
# Generation 485, best fitness = -931.43
# Generation 486, best fitness = -931.43
# Generation 487, best fitness = -931.43
# Generation 488, best fitness = -931.43
# Generation 489, best fitness = -931.43
# Generation 490, best fitness = -931.43
# Generation 491, best fitness = -931.43
# Generation 492, best fitness = -931.43
# Generation 493, best fitness = -931.43
# Generation 494, best fitness = -931.43
# Generation 495, best fitness = -931.43
# Generation 496, best fitness = -931.43
# Generation 497, best fitness = -931.43
# Generation 498, best fitness = -931.43
# Generation 499, best fitness = -931.43

# %%
np.set_printoptions(precision=2, suppress=True)
print("solution:")
print(decode(solution.chromosome, problem))
print(f"The Rosenbrock value is: {- solution.fitness:.2f}")
# Out:
# solution:
# [ 0.21 -0.89  0.44 -0.65  0.78 -0.1  -0.4  -0.6   2.82  8.4 ]
# The Rosenbrock value is: 931.43

# %%
generations = list(range(len(fitness_history)))
plt.figure(figsize=(10, 5))
plt.plot(generations, fitness_history, marker='o', linestyle='-', color='b', label='Best Fitness')

plt.xlabel("Generation")
plt.ylabel("Best Fitness")
plt.title("Fitness Progress Over Generations")
plt.legend()
plt.grid(True)
plt.show()
